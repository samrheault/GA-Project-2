# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a serious of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Check the number of rows and columns.

# %%
# Answer:
movies.shape
# Out:
# (979, 6)

# %% [markdown]
# #### Check the data type of each column.

# %%
# Answer:
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# #### Calculate the average movie duration.

# %%
# Answer:
movies.duration.mean()
# Out:
# 120.97957099080695

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
# Answer:

print("longest movie is", movies.duration.max(), "minutes")
print("shortest movie is", movies.duration.min(), "minutes")
movies.sort_values(by = "duration")
# Out:
# longest movie is 242 minutes
# shortest movie is 64 minutes
#      star_rating                                          title  \
# 389          8.0                                         Freaks
# 338          8.0                            Battleship Potemkin
# 258          8.1                    The Cabinet of Dr. Caligari
# 293          8.1                                      Duck Soup
# 88           8.4                                        The Kid
# 742          7.6                                      Following
# 351          8.0                                   Frankenstein
# 938          7.4                            Alice in Wonderland
# 405          7.9                      The Bride of Frankenstein
# 303          8.0                 The Nightmare Before Christmas
# 713          7.6                                The Jungle Book
# 864          7.5                                          [Rec]
# 489          7.8                     The Triplets of Belleville
# ...

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
# Answer:
movies.duration.hist(bins=15)

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
# Answer:
movies[["duration"]].boxplot();

# %% [markdown]
# ## Intermediate level

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
# Answer:
movies["star_rating"].value_counts().sort_index()
# Out:
# 7.4     49
# 7.5    108
# 7.6    124
# 7.7    113
# 7.8    116
# 7.9     75
# 8.0     97
# 8.1    103
# 8.2     51
# 8.3     43
# 8.4     37
# 8.5     23
# 8.6     15
# 8.7     10
# 8.8      5
# 8.9      6
# 9.0      1
# 9.1      1
# 9.2      1
# 9.3      1
# Name: star_rating, dtype: int64

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
# Answer:
ratings_plot = movies["star_rating"].hist(bins=20)
ratings_plot.set_title('Frequency of Star Ratings', fontsize=21, y=1.01); 
ratings_plot.set_ylabel('Number of Movies', fontsize=16);
ratings_plot.set_xlabel('Star Rating', fontsize=16);

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
# Answer:
row_mask = movies["content_rating"].isin(["NOT RATED", "APPROVED", "PASSED", "GP"])
movies.loc[row_mask, "content_rating"] = "UNRATED"
movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:
row_mask2 = movies["content_rating"].isin(["X","TV-MA"])
movies.loc[row_mask2, "content_rating"] = "NC-17"
movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
movies["content_rating"].value_counts()
# Out:
# R          460
# PG-13      189
# UNRATED    160
# PG         123
# G           32
# NC-17       12
# Name: content_rating, dtype: int64

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
# Answer:
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
# star_rating       979 non-null float64
# title             979 non-null object
# content_rating    976 non-null object
# genre             979 non-null object
# duration          979 non-null int64
# actors_list       979 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:
nullvals = movies["content_rating"].isnull()
np.where(nullvals)[0]
# Out:
# array([187, 649, 936], dtype=int64)

# %%
movies.loc[nullvals, "content_rating"] = "UNRATED"
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
# star_rating       979 non-null float64
# title             979 non-null object
# content_rating    979 non-null object
# genre             979 non-null object
# duration          979 non-null int64
# actors_list       979 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
# Answer:
long_mean = movies[(movies.duration >= 120)].star_rating.mean()
short_mean = movies[(movies.duration < 120)].star_rating.mean()
print("the average star rating for movies 2 hours or longer is", long_mean)
print("the average star rating for movies shorter than 2 hours is", short_mean)
# Out:
# the average star rating for movies 2 hours or longer is 7.948898678414082
# the average star rating for movies shorter than 2 hours is 7.838666666666657

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
# Answer:
movies.plot(kind="scatter", x = "duration", y = "star_rating")

# %%
movies.corr()
# Out:
#              star_rating  duration
# star_rating     1.000000  0.227149
# duration        0.227149  1.000000

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
# Answer:
movies.groupby("genre").duration.mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer:
movies.groupby("content_rating").duration.mean()
# Out:
# content_rating
# G          112.343750
# NC-17      116.250000
# PG         115.300813
# PG-13      127.195767
# R          122.163043
# UNRATED    116.760736
# Name: duration, dtype: float64

# %%
newtable = movies.groupby("content_rating").duration.mean()
plt.plot(newtable)
plt.xlabel("Rating")
plt.ylabel("Average duration")
# Out:
# Text(0,0.5,'Average duration')

# %% [markdown]
# #### Determine the top rated movie (by star rating) for each genre.

# %%
# Answer:
movies.groupby("genre").star_rating.max()
# Out:
# genre
# Action       9.0
# Adventure    8.9
# Animation    8.6
# Biography    8.9
# Comedy       8.6
# Crime        9.3
# Drama        8.9
# Family       7.9
# Fantasy      7.7
# Film-Noir    8.3
# History      8.0
# Horror       8.6
# Mystery      8.6
# Sci-Fi       8.2
# Thriller     8.0
# Western      8.9
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
# Answer:
titlecounts = movies["title"].value_counts()
print(titlecounts[titlecounts > 1])
# Out:
# The Girl with the Dragon Tattoo    2
# Dracula                            2
# Les Miserables                     2
# True Grit                          2
# Name: title, dtype: int64

# %%
dupes = ["True Grit", "The Girl with the Dragon Tattoo", "Dracula", "Les Miserables"]
duplicates = movies.loc[(movies["title"].isin(dupes))]
duplicates.sort_values(by="title")
# Out:
#      star_rating                            title content_rating      genre  \
# 703          7.6                          Dracula        UNRATED     Horror
# 905          7.5                          Dracula              R     Horror
# 678          7.7                   Les Miserables          PG-13      Drama
# 924          7.5                   Les Miserables          PG-13      Crime
# 466          7.9  The Girl with the Dragon Tattoo              R      Crime
# 482          7.8  The Girl with the Dragon Tattoo              R      Crime
# 662          7.7                        True Grit          PG-13  Adventure
# 936          7.4                        True Grit        UNRATED  Adventure
#
#      duration                                        actors_list
# 703        85  [u'Bela Lugosi', u'Helen Chandler', u'David Ma...
# 905       128  [u'Gary Oldman', u'Winona Ryder', u'Anthony Ho...
# 678       158  [u'Hugh Jackman', u'Russell Crowe', u'Anne Hat...
# ...

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
# Answer:

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
# Answer:
genrecounts = movies["genre"].value_counts()
relevant = genrecounts[genrecounts>=10]

relevant_genres = list(relevant.index.values)
print(relevant_genres)

this_table = movies.groupby("genre").star_rating.mean()
this_table.loc[relevant_genres]
# Out:
# ['Drama', 'Comedy', 'Action', 'Crime', 'Biography', 'Adventure', 'Animation', 'Horror', 'Mystery']
# genre
# Drama        7.902518
# Comedy       7.822436
# Action       7.884559
# Crime        7.916935
# Biography    7.862338
# Adventure    7.933333
# Animation    7.914516
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Figure out something "interesting" using the actors data!
